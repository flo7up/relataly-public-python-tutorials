# %%
# Tested with Python 3.8.8, Matplotlib 3.5, Scikit-learn 0.24.1, Seaborn 0.11.1, numpy 1.19.5

# %% [markdown]
# # Lineplot

# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

#define the dataframe
fig, ax = plt.subplots(figsize=[10, 5])
df = pd.DataFrame({"date":["01/2022", "02/2022", "03/2022", "04/2022", 
                           "05/2022", "06/2022", "07/2022", "08/2022"], 
                   "quantities sold":[1,5,7,4,5, 10, 9, 14]})

# display the plot
print(df)
sns.lineplot(data = df, y='quantities sold', x='date', color='royalblue')
ax.tick_params(axis="x", rotation=0, labelsize=10, length=0)
ax.set_title('Lineplot')
plt.show()
# Out:
#       date  quantities sold
# 0  01/2022                1
# 1  02/2022                5
# 2  03/2022                7
# 3  04/2022                4
# 4  05/2022                5
# 5  06/2022               10
# 6  07/2022                9
# 7  08/2022               14

# %% [markdown]
# # Barplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# define the dataframe 
df = pd.DataFrame({"car types":["sedans", "cabrios", "convertibles", "coupes", "minivans", "hatchbacks"], "quantities sold":[1,5,3,4,5,10]})


# display the plot
fig, axs = plt.subplots(figsize=[10, 5], ncols=2, nrows=1)
sns.barplot(data=df, y='car types', x='quantities sold', ax=axs[0], palette='pastel')
axs[0].tick_params(axis="x", rotation=0, labelsize=10, length=0)
axs[0].set_title('Barplot horizontal')
sns.barplot(data=df, x='car types', y='quantities sold', ax=axs[1], palette='pastel')
axs[1].tick_params(axis="x", rotation=90, labelsize=10, length=0)
axs[1].set_title('Barplot vertical')
plt.show()

# %% [markdown]
# # Countplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# define the dataframe 
df = sns.load_dataset("titanic")

# display the plot
fig, ax = plt.subplots(figsize=[10, 5])
sns.countplot(data=df, x='class', hue='sex')
plt.title('countplot')
plt.show()

# %% [markdown]
# # Histplot

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# define the dataframe
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# display the plot
print(s)
fig, ax = plt.subplots(figsize=(10, 5))
sns.histplot(s, linewidth=2, color='royalblue', kde=True, ax=ax)
ax.tick_params(axis="x", rotation=0, labelsize=10, length=0)
ax.set_title('Histplot')
plt.show()
# Out:
# [ 5.54017799e-03 -7.03737551e-02 -2.68150468e-01  8.02665413e-02
#  -8.27792562e-02 -4.72757959e-02 -1.08551276e-01 -1.37886304e-01
#  -8.78526369e-02  1.72948031e-03 -1.47795645e-02  4.67929007e-02
#   2.13913136e-01  3.61434477e-02  1.30659231e-01  9.40785220e-02
#  -1.78319377e-01 -1.71170092e-02 -3.80816374e-02  9.52226243e-02
#   5.46994966e-02 -4.06047682e-02 -1.73992898e-02  1.26641920e-01
#   6.63256866e-02  7.77387813e-03  7.44408093e-02 -1.92787562e-01
#  -9.65162091e-02 -2.64173667e-02  2.24323003e-02  2.03550881e-02
#  -9.86731657e-02  6.16424379e-02  1.87775930e-01 -5.11311830e-02
#   6.83656150e-02  9.06759433e-02  2.19158093e-01 -8.80055783e-02
#  -3.24710426e-01  2.01076506e-01  3.50208667e-02 -1.50268142e-01
#   2.97465090e-03 -1.61499838e-01 -1.62386209e-01 -4.41498145e-02
#   2.19953593e-01  3.73629909e-02 -1.34671760e-02 -1.56810412e-01
#   4.07807799e-02 -4.91796125e-02  1.14785609e-01 -3.59255405e-02
# ...

# %% [markdown]
# # Displot (Density Plot)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# define the dataframe
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
z = np.random.normal(mu, sigma, 1000)
f = np.random.normal(mu, sigma, 1000)

df = pd.DataFrame({'s':s, 'z':z, 'f':f})

# display the plot
sns.displot(data=df, linewidth=2, kind='kde', height=5, aspect=2)
plt.title('Density Plot')
plt.show()

# %% [markdown]
# # Scatterplot

# %%
from matplotlib import pyplot as plt
import random
import seaborn as sns
import pandas as pd

# define the dataframe
x, y, z = [], [], []
for i in range(0,50):
    x.append(random.randint(1,50))
    y.append(random.randint(1,50))
    z.append(random.choice(['a', 'b', 'c']))
df = pd.DataFrame({'x':x, 'y':y, 'z':z})

# display the plot
print(df)
fig, ax = plt.subplots(figsize=[10, 5])
sns.scatterplot(data=df, x=x, y=y, hue=z, color='red')
ax.tick_params(axis="x", rotation=0, labelsize=10, length=0)
ax.set_title('Scatterplot')
plt.show()
# Out:
#      x   y  z
# 0   40  25  b
# 1   12  16  a
# 2   48  26  a
# 3   45  44  b
# 4   43  17  c
# 5   40  21  b
# 6   12   5  c
# 7   38  33  b
# 8   12  15  b
# 9   11  16  a
# 10  11   4  b
# 11   7  20  c
# 12  38  15  c
# 13  35  49  a
# 14   2  38  c
# 15  27  16  b
# 16  10  50  a
# 17  46  14  a
# 18   8  25  c
# 19  34  30  b
# 20   2  19  c
# 21  39  30  a
# 22   1  38  a
# 23  16  20  a
# 24  29  36  a
# 25  25  37  c
# 26  12  20  b
# 27  10  13  a
# 28  15  42  b
# 29  30   7  b
# 30  22  18  c
# 31  41  25  a
# 32  31  15  b
# 33  16  35  c
# 34  45  30  a
# 35  48  46  a
# 36  49  43  a
# 37  33  33  c
# 38  18  45  b
# 39  45  29  a
# 40   6  30  b
# 41  22  16  c
# 42  39  37  c
# 43  10  14  a
# 44  48  40  a
# 45  32  48  b
# 46  20  14  c
# 47  24  23  c
# 48  32  23  b
# 49  45  19  c

# %% [markdown]
# # Pieplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# define the dataframe 
df = pd.DataFrame({"fruits":["strawberry", "apple", "peach", "pienaple", "blueberry", "cherry"], "sold":[1,5,3,4,5,10]})

# display the plot
colors = sns.color_palette('pastel')[0:6]
fig, ax = plt.subplots(figsize=[7, 7])
plt.pie(data=df, x='sold', labels='fruits', colors=colors)
ax.tick_params(axis="x", rotation=0, labelsize=10, length=0)
ax.set_title('Pieplot')
plt.show()

# %% [markdown]
# # Heatmap

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

corr = ([[ 1., -0.04, -0.20, -0.24],
       [-0.05,  1.,  0.12, -0.29],
       [-0.20,  0.4,  1.,  0.25],
       [-0.24, -0.29,  0.28 ,  1.]])

# Generate a custom diverging colormap
cmap = "RdBu"

# Draw the heatmap
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(
    corr,
    cmap=cmap,
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.5},
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Boxplot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# define the dataframe
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

df = pd.DataFrame({'s':s})

# box plot design
PROPS = {
    'boxprops':{'facecolor':'none', 'edgecolor':'royalblue'},
    'medianprops':{'color':'coral'},
    'whiskerprops':{'color':'royalblue'},
    'capprops':{'color':'royalblue'}
    }
sns.set_style('ticks', {'axes.edgecolor': 'grey',  
                        'xtick.color': '0',
                        'ytick.color': '0'})

# display the plot
fig, ax = plt.subplots(figsize=[10,2])
sns.boxplot(data=df, orient="h", ax = ax, color='royalblue', flierprops={"marker": "o"}, **PROPS)
plt.show()

# %% [markdown]
# # Violin Plot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# define the dataframe
mu, sigma = 0, 0.1 # mean and standard deviation

f, s, t = [], [], []
for i in range(50):
    f.append(np.random.choice([True, False]))
    t.append(np.random.choice(['A', 'B', 'C']))
    s.append(np.random.randint(1,50))
df = pd.DataFrame({'s':s, 'f':f, 't':t})

# display the plot
fig, ax = plt.subplots(figsize=[10,5])
sns.violinplot(data=df, y='s', x='t', hue='f', split=True, ax=ax)
ax.set_title('Violin plot')
plt.show()
