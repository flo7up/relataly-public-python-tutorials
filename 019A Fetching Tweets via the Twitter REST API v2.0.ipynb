# %% [markdown]
# # Retrieving Tweets by Searchtag

# %%
import requests 
import json 
import pandas as pd

# imports the twitter_secrets python file in which we store the twitter API keys
from twitter_secrets import twitter_secrets as ts

# puts the bearer token in the request header
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers
        
# sets the rules on which tweets to retrieve    
def set_rules(headers, delete, bearer_token, rules):
    payload = {"add": rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    
# retrieves the current set of rules from the API     
def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

# tells the API to delete our current rule configuration 
def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

# starts the stream, iterates through the lines of the response and for each line calls the save_tweets function
def get_stream(headers, set, bearer_token, expansions, fields):
    data = []
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream" + expansions + fields, headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    i = 0
    for response_line in response.iter_lines():
        i += 1
        if i == max_results:
            break
        else:
            json_response = json.loads(response_line)
            #print(json.dumps(json_response, indent=4, sort_keys=True))
            try:
                save_tweets(json_response)
            except (json.JSONDecodeError, KeyError) as err:
                # In case the JSON fails to decode, we skip this tweet
                print(f"{i}/{max_results}: ERROR: encountered a problem with a line of data... \n")
                continue

# appends information from tweets to a dataframe                
def save_tweets(tweet):
    print(json.dumps(tweet, indent=4, sort_keys=True))
    data = tweet['data']
    public_metrics = data['public_metrics']
    tweet_list.append([data['id'], data['author_id'], data['created_at'], data['text'], public_metrics['like_count']])

# the max number of tweets that will be returned
max_results = 20

# You can adjust the rules if needed
search_rules = [
    {"value": "dog has:images", "tag": "dog pictures", "lang": "en"},
    {"value": "cat has:images -grumpy", "tag": "cat pictures", "lang": "en"},
]

# defines the fields which we want to retrieve
tweet_fields = "?tweet.fields=attachments,author_id,created_at,public_metrics"

# we only retrieve the tweet object, but if we wanted to retrieve other objects (e.g., media), we would add them to the expansions string
expansions = ""
tweet_list = []

bearer_token = ts.BEARER_TOKEN
headers = create_headers(bearer_token)
rules = get_rules(headers, bearer_token)
delete = delete_all_rules(headers, bearer_token, rules)
set = set_rules(headers, delete, bearer_token, search_rules)
get_stream(headers, set, bearer_token, expansions, tweet_fields)

df = pd.DataFrame (tweet_list, columns = ['tweetid', 'author_id' , 'created_at', 'text', 'like_count'])
df
# Out:
# {"data": [{"id": "1345871235985584128", "value": "dog has:images", "tag": "dog pictures"}], "meta": {"sent": "2021-01-05T12:14:43.176Z"}}
# {"meta": {"sent": "2021-01-05T12:14:44.455Z", "summary": {"deleted": 1, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1346429926728232962"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1346429926728232961"}], "meta": {"sent": "2021-01-05T12:14:45.743Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "author_id": "1333943095562547202",
#         "created_at": "2021-01-05T12:14:36.000Z",
#         "id": "1346429891139543041",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "@JuntsXCat @LauraBorras @MovEsquerres https://t.co/m9onumGTHF\nFIL sobre Albert Donaire @albertdmcat, un intolerant a les llistes de @JuntsXCat"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346382364591603718"
#             ]
#         },
#         "author_id": "102741844",
#         "created_at": "2021-01-05T12:14:36.000Z",
#         "id": "1346429891353272321",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 20
#         },
#         "text": "RT @tanu_mfmf: \u3082\u3061\u308d\u3093\u3042\u305f\u3061\u3082\u53c2\u52a0\u3057\u307e\u30fc\u3059\ud83d\udc31\n #\u3069\u3046\u3076\u3064\u306b\u30cf\u30c6\u30ca\u3064\u3051\u308b\u3068\u53ef\u611b\u3044\u9078\u624b\u6a29\n\n#\u732b\u306e\u3044\u308b\u66ae\u3089\u3057 #\u732b #\u306d\u3053 #cat #cats #\u4fdd\u8b77\u732b #CatsOfTwitter https://t.co/FRqqiLNJ3P"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1319465137909055488",
#         "created_at": "2021-01-05T12:14:36.000Z",
#         "id": "1346429893928620034",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 50
#         },
#         "text": "RT @LivetubeSTAR: \u30b7\u30e3\u30c9\u30d0\u30e6\u30fc\u30b6\u30fc\u5927\u4f1a \u325a\u5206\u5f8c\u306b\u958b\u50ac\n\u30ed\u30fc\u30c6BO3 \u30c7\u30c3\u30ad\u56fa\u5b9a \u8ca0\u3051\u305f\u3089\u5373\u7d42\u4e86\u3000\n\u6700\u5f8c\u307e\u3067\u751f\u304d\u6b8b\u3063\u305f\u6700\u591a\u52dd\u5229\u6570\u306e\u4eba\u304c\u512a\u52dd\u3002\n\u512a\u52dd\u8005\u6c7a\u307e\u308b\u307e\u3067\u30b5\u30c9\u30f3\u30c7\u30b9\n\u89b3\u6226\u3059\u308b\u53ef\u80fd\u6027\u3042\u308a\u307e\u3059\u3002\n\u512a\u52dd\u8cde\u91d11000\u5186\u30b9\u30dd\u30f3\u30b5\u30fc\u306d\u3053\u306b\u3093\u3055\u3093@Cat_Ciel_73\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1243377247899222019",
#         "created_at": "2021-01-05T12:14:37.000Z",
#         "id": "1346429895530967045",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 7
#         },
#         "text": "RT @AgentSquirrel45: @pann4trump @GAsandwich @lexi10292 @UnitedWeStandDT @BCM_SOLT @janicem59758122 @qfd_bruce @slimefin @MeltingInMarana @\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1315998706110468096",
#         "created_at": "2021-01-05T12:14:37.000Z",
#         "id": "1346429896478875648",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 52
#         },
#         "text": "RT @AureMagik: New NSFW from the Curious Cat suggestion ! It was pretty fun to do \ud83d\ude0e\n\n(I used a pic reference too) \n\nWith many scratches and\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346381062885163011"
#             ]
#         },
#         "author_id": "1192444764966113280",
#         "created_at": "2021-01-05T12:14:37.000Z",
#         "id": "1346429897229537285",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 1629
#         },
#         "text": "RT @tanu_mfmf: \u307f\u305f\u3089\u3057\u53c2\u6226\u3057\u307e\u3059\ud83d\ude38\n #\u3069\u3046\u3076\u3064\u306b\u30cf\u30c6\u30ca\u3064\u3051\u308b\u3068\u53ef\u611b\u3044\u9078\u624b\u6a29\n\n#\u732b\u306e\u3044\u308b\u66ae\u3089\u3057 #\u732b #\u306d\u3053 #cat #cats #\u4fdd\u8b77\u732b #CatsOfTwitter https://t.co/OYLvwYPzRv"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346302636304175104"
#             ]
#         },
#         "author_id": "1238428065811718145",
#         "created_at": "2021-01-05T12:14:38.000Z",
#         "id": "1346429899150483457",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 303
#         },
#         "text": "RT @niszbeyo: @afiqxsy_ A cat lover\u2019s feeling after watching this : \ud83e\udd21\ud83e\udd1b\ud83c\udffb\ud83e\udd1b\ud83c\udffb https://t.co/oQn5Li3HJb"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1126268686476632064",
#         "created_at": "2021-01-05T12:14:38.000Z",
#         "id": "1346429901142806528",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 290
#         },
#         "text": "RT @jenniedebuts: The caption of this online reseller selling these hanboks for dogs. \ud83d\ude2d\n\n\"Blackpink Jennie's pet dog has also worn this\" Ku\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232961,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346429894746632194"
#             ]
#         },
#         "author_id": "1142880804223225858",
#         "created_at": "2021-01-05T12:14:38.000Z",
#         "id": "1346429900975124480",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Hi folks! \ud83d\ude0a I hope everyone is keeping safe &amp; well. \u263a\ufe0f I thought I\u2019d share with you all my first #tshirt of the year, it\u2019s this adorable #Pusheen t-shirt which I love! \u2764\ufe0f My partner @that_uk_gamer got me it for Christmas. \ud83e\udd70 Which #cat on the shirt is your fave? \ud83d\ude38 #catlovers https://t.co/t4W3LoJBuh"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1343227823226576897",
#         "created_at": "2021-01-05T12:14:39.000Z",
#         "id": "1346429903391105024",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 120
#         },
#         "text": "RT @HamDried: You guys, my dog died today.  She had congestive heart failure and was getting worse.  Took her to the vet, and they put her\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232961,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "758964766891139073",
#         "created_at": "2021-01-05T12:14:39.000Z",
#         "id": "1346429903651168258",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 4
#         },
#         "text": "RT @Th3DutchZombi3: Game: The Last of Us Part II\nDeveloper: @Naughty_Dog\nPlatform: #PS4Pro #PS4 \n\n#VirtualPhotography #Gametography #VGPUni\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232961,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346381062885163011"
#             ]
#         },
#         "author_id": "109838901",
#         "created_at": "2021-01-05T12:14:39.000Z",
#         "id": "1346429904930230273",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 1629
#         },
#         "text": "RT @tanu_mfmf: \u307f\u305f\u3089\u3057\u53c2\u6226\u3057\u307e\u3059\ud83d\ude38\n #\u3069\u3046\u3076\u3064\u306b\u30cf\u30c6\u30ca\u3064\u3051\u308b\u3068\u53ef\u611b\u3044\u9078\u624b\u6a29\n\n#\u732b\u306e\u3044\u308b\u66ae\u3089\u3057 #\u732b #\u306d\u3053 #cat #cats #\u4fdd\u8b77\u732b #CatsOfTwitter https://t.co/OYLvwYPzRv"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346418050136850433",
#                 "3_1346418054415011840"
#             ]
#         },
#         "author_id": "1194864769137725440",
#         "created_at": "2021-01-05T12:14:39.000Z",
#         "id": "1346429904997371904",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 80
#         },
#         "text": "RT @blckvlvtinferno: This picture of Wonwoo reminds me of the cat. It seems similar \ud83d\ude39 https://t.co/rdoMj9n6al"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "4551114496",
#         "created_at": "2021-01-05T12:14:40.000Z",
#         "id": "1346429908474605568",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 4
#         },
#         "text": "RT @AdoptionsUk: Please retweet to help Fergus find a home #WORCESTERSHIRE \ud83c\uddec\ud83c\udde7\n\nAged 2-5, desperate to find a adult calm, home, secure garde\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232961,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346429906100445184",
#                 "3_1346429906096246784"
#             ]
#         },
#         "author_id": "898028489005125634",
#         "created_at": "2021-01-05T12:14:40.000Z",
#         "id": "1346429911305621508",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "my cat on the enstar https://t.co/qpmbfaxBo0"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1346429909669801985"
#             ]
#         },
#         "author_id": "767644583266136064",
#         "created_at": "2021-01-05T12:14:41.000Z",
#         "id": "1346429911792173062",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Cat recognition (Tensorflow 1.10)\ntabby, tabby cat (score = 0.04788) https://t.co/5gnfza4AQ2"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "721093856960188416",
#         "created_at": "2021-01-05T12:14:41.000Z",
#         "id": "1346429912253571073",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 2
#         },
#         "text": "RT @Kikuchi_city: \uff0f\n\ud83d\udd25\u706b\u306e\u7528\u5fc3!\u30de\u30c3\u30c1\u4e00\u672c\u706b\u4e8b\u306e\u3082\u3068\u5c55\uff20\u4e2d\u592e\u56f3\u66f8\u9928\n\uff3c\n1\u670826\u65e5\u306e\u6587\u5316\u8ca1\u9632\u706b\u30c7\u30fc\u306b\u5408\u308f\u305b\u3001\u4e2d\u592e\u56f3\u66f8\u9928\u306e\u5165\u53e3\u306e\u5c55\u793a\u5ba4\u3067\u306f\u8fd1\u4e16\u306e\u83ca\u6c60\u95a2\u9023\u8cc7\u6599\u3084\u53e4\u3044\u30de\u30c3\u30c1\u7bb1\u306a\u3069\u3092\u5c55\u793a\u4e2d\ud83d\ude00\u305a\u3089\u308a\u3068\u4e26\u3076\u30de\u30c3\u30c1\u7bb1\u306f\u5fc5\u898b\u2757\n\u5e02\u5185\u306e\u30de\u30c3\u30c1\u30e9\u30d9\u30eb\u3092\u30c7\u30b8\u30bf\u30eb\u30a2\u30fc\u30ab\u30a4\u30d6\u306b\u3066\u516c\u958b\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1247305749824524288",
#         "created_at": "2021-01-05T12:14:42.000Z",
#         "id": "1346429916183715840",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "\"mon ch\u00e9ri\" kfksjfjdjd CUTE https://t.co/ok8xyATfbe"
#     },
#     "matching_rules": [
#         {
#             "id": 1346429926728232962,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         